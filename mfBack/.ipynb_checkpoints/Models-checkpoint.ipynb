# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.statespace.sarimax import SARIMAX
from pmdarima import auto_arima
from sklearn.model_selection import train_test_split
from statsmodels.tsa.ar_model import AutoReg
from statsmodels.graphics.tsaplots import plot_pacf,plot_acf
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
df = pd.read_pickle("cleaned_nifty50.pkl")
print(df.head(6))
# Out:
#         Time     Price
# 0 2025-03-11  22497.90
# 1 2025-03-10  22460.30
# 2 2025-03-07  22552.50
# 3 2025-03-06  22544.70
# 4 2025-03-05  22337.30
# 5 2025-03-04  22082.65

# %%
train_cutoff = "2024-03-12"

df["Time_numeric"] = df["Time"].map(pd.Timestamp.toordinal)

df_train = df[df["Time"] <= train_cutoff]  
df_test = df[df["Time"] > train_cutoff]   

print("Training Data Shape:", df_train.shape)
print("Testing Data Shape:", df_test.shape)
# Out:
# Training Data Shape: (8181, 3)
# Testing Data Shape: (248, 3)

# %%
print(df_train["Time"].max())  
print(df_test["Time"].min())
# Out:
# 2024-03-12 00:00:00
# 2024-03-13 00:00:00

# %%
#Dicky Fuller Test for Stationary Check
result = adfuller(df_train["Price"])
print("ADF Statistic:", result[0])
print("p-value:", result[1])

if result[1] < 0.05:
    print("Data is stationary ✅")
else:
    print("Data is NOT stationary ❌")
# Out:
# ADF Statistic: -3.9671716032063298
# p-value: 0.0015925095396845765
# Data is stationary ✅

# %%
#Seasonal Decomposition for Seasonality
result = seasonal_decompose(df_train["Price"], model="additive", period=12)

result.plot()
plt.show()

# %%
#ACF Test for Seasonality
plot_acf(df_train["Price"], lags=8000)
plt.show()

# %%
#Augmented Dickey Fuler Test
from statsmodels.tsa.stattools import adfuller

dftest = adfuller(df['Price'], autolag='AIC')

print("1. ADF : ", dftest[0])
print("2. P-Value : ", dftest[1])
print("3. Num Of Lags : ", dftest[2])
print("4. Num Of Observations Used For ADF Regression and Critical Values Calculation : ", dftest[3])
print("5. Critical Values : ")
for key, val in dftest[4].items():
    print("\t", key, ":", val)
# Out:
# 1. ADF :  -3.606571057288757
# 2. P-Value :  0.005636638754120351
# 3. Num Of Lags :  37
# 4. Num Of Observations Used For ADF Regression and Critical Values Calculation :  8391
# 5. Critical Values :
# 	 1% : -3.4311295616261313
# 	 5% : -2.861884512591697
# 	 10% : -2.566953379187634

# %% [markdown]
# ### LINEAR REGRESSION

# %%
X_train = df_train[["Time_numeric"]]
y_train = df_train["Price"]

X_test = df_test[["Time_numeric"]]
y_test = df_test["Price"]

# %%
from sklearn.linear_model import LinearRegression

lr_model = LinearRegression()
lr_model.fit(X_train, y_train)

y_pred = lr_model.predict(X_test)

# %%
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print(f"Mean Absolute Error (MAE): {mae}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
# Out:
# Mean Absolute Error (MAE): 9892.287674461799
# Root Mean Squared Error (RMSE): 9946.369475691063

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_test["Time"], y_test, label="Actual Price", color="blue")
plt.plot(df_test["Time"], y_pred, label="Linear Regression Prediction", color="red", linestyle="dashed")
plt.xlabel("Time")
plt.ylabel("Price")
plt.title("Linear Regression: Actual vs Predicted")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### AR Model

# %%
print(df_train.head(5))
# Out:
#           Time     Price  Time_numeric
# 248 2024-03-12  22335.70        738957
# 249 2024-03-11  22332.65        738956
# 250 2024-03-07  22493.55        738952
# 251 2024-03-06  22474.05        738951
# 252 2024-03-05  22356.30        738950

# %%
#In ar model we are only concerned about the Past Values and nothing else So...
print('Shape of Data:',df.shape)
#Extracting only values
x_ar = df["Price"].values
print('Extracted Price values for AR:\n ',x_ar)
# Out:
# Shape of Data: (8429, 3)
# Extracted Price values for AR:
#   [22497.9  22460.3  22552.5  ...   289.04   284.04   279.02]

# %%
pacf=plot_pacf(df['Price'],lags=85)
acf=plot_acf(df['Price'],lags=85)

# %%
print(len(x_ar))
# Out:
# 8429

# %%
train_ar = x_ar[248:]  
test_ar = x_ar[:248]

# %%
print('x_ar length:', len(x_ar))
print('train_ar length:', len(train_ar))
print('test_ar length:', len(test_ar))
# Out:
# x_ar length: 8429
# train_ar length: 8181
# test_ar length: 248

# %%
ar_model=AutoReg(train_ar,lags=1).fit()

# %%
print(ar_model.summary())
# Out:
#                             AutoReg Model Results
# ...
# Dep. Variable:                      y   No. Observations:                 8181
# Model:                     AutoReg(1)   Log Likelihood              -47193.103
# Method:               Conditional MLE   S.D. of innovations             77.509
# Date:                Fri, 14 Mar 2025   AIC                          94392.206
# Time:                        01:05:54   BIC                          94413.235
# Sample:                             1   HQIC                         94399.396
#                                  8181
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0067      1.231      0.818      0.413      -1.405       3.418
# y.L1           0.9993      0.000   6130.943      0.000       0.999       1.000
#                                     Roots
# ...

# %%
predictions = ar_model.predict(start=len(train_ar), end=len(train_ar) + len(test_ar) - 1)

# %%
mae = mean_absolute_error(test_ar,predictions)
rmse = np.sqrt(mean_squared_error(test_ar,predictions))

print(f"Mean Absolute Error (MAE): {mae}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
# Out:
# Mean Absolute Error (MAE): 23355.769981975915
# Root Mean Squared Error (RMSE): 23380.51988676835

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_test["Time"], test_ar, label="Actual Price", color="blue")
plt.plot(df_test["Time"], predictions, label="AR Prediction", color="red", linestyle="dashed")
plt.xlabel("Time")
plt.ylabel("Price")
plt.title("AR Model: Actual vs Predicted")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_test["Time"], y_test, label="Actual Price", color="blue")
plt.plot(df_test["Time"], y_pred, label="Linear Regression Prediction", color="red", linestyle="dashed")
plt.xlabel("Time")
plt.ylabel("Price")
plt.title("Linear Regression: Actual vs Predicted")
plt.legend()
plt.grid(True)
plt.show()
